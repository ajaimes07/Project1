# %%
# Title:     HousePy_Group5__Aline_V3
# Authors:   Aline J
# Date:      09/10/19
# Goal:      Analysis of the housing market in the Houston Area from 2015-2017
# Questions: 
#1) Which market areas have properties with more/less days  in the market
#2) Which are the drivers of housing Market in the Houston Area from 2015-2017

### Begins Here ####
# 1. Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import numpy as np
import string as string
import warnings
warnings.filterwarnings('ignore')

# 2. Import Raw data file into a data frame
csv_path = "Data/Housepy_raw.csv"
housepyraw_df = pd.read_csv(csv_path)
#housepyraw_df.head()
#housepyraw_df.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-8d348ed6051b> in <module>
#      19 # 2. Import Raw data file into a data frame
#      20 csv_path = "Data/Housepy_raw.csv"
# ---> 21 housepyraw_df = pd.read_csv(csv_path)
#      22 #housepyraw_df.head()
#      23 #housepyraw_df.columns
#
# ...

# %%
#3. Subset dataframe: Dropping columns that wont be used to tell us anything
housepy_df = housepyraw_df[["Zip Code", "List Price", "Close Price", "Close Date", "Area", "Market Area", "School District",
                          "Sq Ft Total", "Price Sq Ft Sold", "Lot Size", "Year Built", "Bedrooms", "Baths Total", "CDOM"]]
#housepy_df.head()
#housepy_df.dtypes
# 4. Identify data types 
#housepy_df.dtypes
# 5. Replace $ from column
housepy_df['Close Price'] = housepy_df['Close Price'].apply(lambda x: x.replace("$", ""))
housepy_df['Close Price'] = housepy_df['Close Price'].apply(lambda x: x.replace(",", ""))
housepy_df['Close Price'] = housepy_df['Close Price'].astype(int)

housepy_df['List Price'] = housepy_df['List Price'].apply(lambda x: x.replace("$", ""))
housepy_df['List Price'] = housepy_df['List Price'].apply(lambda x: x.replace(",", ""))
housepy_df['List Price'] = housepy_df['List Price'].astype(int)
#housepy_df.head()

# %%
#. How many MArket Areas?
#AreasGroup =housepy_df.groupby('Market Area')
#AreasGroup.head()
#count_Areas = AreasGroup['Market Area'].count()
#count_Areas
#count_Areas=count_Areas.plot(kind='bar')
# 102

# %%
#. How many Areas?
#AreasGroup =housepy_df.groupby('Area')
#AreasGroup.head()
#count_Areas = AreasGroup['Area'].count()
#count_Areas
#count_Areas=count_Areas.plot(kind='bar')
# 86

# %%
#. How many School Districts?
#SchoolDistrictGroup =housepy_df.groupby('School District')
#SchoolDistrictGroup.head()
#count_District = SchoolDistrictGroup['School District'].count()
#count_District
#count_District=count_District.plot(kind='bar')
#23

# %%
#. How many Zipcodes?
#ZCGroup =housepy_df.groupby('Zip Code')
#ZCGroup.head()
#count_ZC = ZCGroup['Zip Code'].count()
#count_ZC
#count_ZC=count_ZC.plot(kind='bar')
# 129

# %%
# What are the market areas with properties with more days in the market
df = housepy_df.groupby(['Market Area']).mean()
#classes = housepy_df.groupby(['CDOM','Close Date','List Price','Market Area'])
# Preview DataFrame
#classes.head(100)
#classes.dtypes

DescriptiveStats=df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-531e44b217cb> in <module>
#       1 # What are the market areas with properties with more days in the market
# ----> 2 df = housepy_df.groupby(['Market Area']).mean()
#       3 #classes = housepy_df.groupby(['CDOM','Close Date','List Price','Market Area'])
#       4 # Preview DataFrame
#       5 #classes.head(100)
#
# NameError: name 'housepy_df' is not defined

# %%
# What are the School district with properties with more days in the market
#classes = housepy_df.groupby(['School District']).mean()
#classes = housepy_df.groupby(['CDOM','Close Date','List Price','Market Area'])
# Preview DataFrame
#classes.head(10)

# %%
# What are the Market areas with more/less days in the market?

# What are the School district with properties with more days in the market
df = housepy_df.groupby(['Market Area']).mean()
#df=housepy_df.groupby(['Market Area','School District']).mean()
df=df.dropna()
# Preview DataFrame
df.head(5)
# Out:
#                               Zip Code     List Price    Close Price  \
# Market Area
# 1960/Cypress              77065.000000  199878.748808  195227.662957
# 1960/Cypress Creek North  77079.121508  207676.377793  201742.322626
# 1960/Cypress Creek South  77054.375706  162773.096673  159456.775267
# Aldine Area               77063.411507  146092.163843  142376.018107
# Alief                     77080.169330  182729.837149  178043.177970
#
#                                Area  Sq Ft Total      Lot Size   Year Built  \
# Market Area
# 1960/Cypress              10.116057  2155.307080  10035.665597  1987.388712
# 1960/Cypress Creek North  13.057263  2804.455944  12433.456964  1982.190642
# 1960/Cypress Creek South  13.036095  2096.840945   7356.938732  1993.771743
# Aldine Area               16.200643  1839.332254   8146.311971  1993.070134
# Alief                     28.499784  2001.523851   5962.048047  1988.240173
#
#                           Bedrooms  Baths Total       CDOM
# ...

# %%
# Do it after the data has been cleaned
#classes.dtypes
#df1=classes.reset_index()
#df1.head(50)

# %%
# %matplotlib notebook
# Market Area and CDOM
# Assign plots to tuples that stores result of plot
# Each point on the sine chart is marked by a blue circle

#sine_handle, = plt.plot(x_axis, sin, marker ='o', color='blue', label="Sine")
# Each point on the cosine chart is marked by a red triangle
#cosine_handle, = plt.plot(x_axis, cos, marker='^', color='red', label="Cosine")
# Adds a legend and sets its location to the lower right
#plt.legend(loc="lower right")
# Saves an image of our chart so that we can view it in a folder
#plt.savefig("../Images/lineConfig.png")
#plt.show()

# %%
#Cleaning Data
# Descriptive statistics 
#DescriptiveStats=classes.describe()
#DescriptiveStats.head()
DescriptiveStats=df.describe()
DescriptiveStats.head()
# Out:
#            Zip Code     List Price    Close Price        Area  Sq Ft Total  \
# count    100.000000     100.000000     100.000000  100.000000   100.000000
# mean   77120.184126  527330.142381  502867.985626   14.050122  2609.871997
# std      148.297415  597368.953403  550623.805708    9.133637  1172.281312
# min    77002.666667  104971.428571  100000.000000    1.000000  1367.400000
# 25%    77026.937697  195813.937326  190528.666648    6.998936  1993.709555
#
#            Lot Size   Year Built    Bedrooms  Baths Total        CDOM
# count    100.000000   100.000000  100.000000   100.000000  100.000000
# mean   11690.218019  2100.052618    3.484229     2.495241   88.970044
# std    18685.872624  1142.170181    0.464679     0.699419   55.985324
# min     2144.000000  1950.571429    2.333333     1.431250    6.500000
# 25%     7061.501309  1978.000000    3.202542     2.084048   50.644828

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Close Price'], df['CDOM'])
ax.set_xlabel('Close Close')
ax.set_ylabel('List Price')
plt.show()

# %%
#df.columns
# Exploratory plots
# Boxplot to depict groups of numerical data
import seaborn as sns
#fig, ax = plt.subplots(figsize=(16,8))
#ax = df.plot.line(subplots=True,figsize=(20,8))
#type(ax)
#class 'numpy.ndarray'
#ax = df.boxplot(subplots=false,figsize=(20,8))

#fig, ax = plt.subplots(figsize=(16,8))
#type(ax)
#boxplot = df.boxplot(column=['CDOM', 'Sq Ft Total', 'Lot Size', 'Year Built', 'Bedrooms', 'CDOM'])

dfNew = df[(df['List Price']<600000) & (df['List Price']>10) & (df['Close Price']<600000) & (df['Close Price']>10) & (df['Lot Size']<600000) & (df['Lot Size']<13000)& (df['CDOM']<1500)]
print('{}, {}'.format(len(df), len(dfNew)))
boxplot = dfNew.boxplot(column=['List Price', 'Close Price', 'CDOM', 'Sq Ft Total', 'Lot Size', 'Year Built', 'Bedrooms', 'CDOM'])
# Out:
# 100, 73
# <img src="data:image/png;base64,..." width="640">

# %%
#housepy_df.dtypes
# -----------------------------------------------
# Detecting Outliers: Z-Score
# The Z-score is the signed number of standard deviations by which the value of an observation or data point is 
# above the mean value of what is being observed or measured.
# Z-score is to describe any data point by finding their relationship with the Standard Deviation and Mean of the 
# group of data points. Z-score is finding the distribution of data where mean is 0 and standard deviation 
# is 1 i.e. normal distribution.
# -----------------------------------------------
from scipy import stats
import numpy as np
#z = np.abs(stats.zscore(dfT["Close Price"]))
z = np.abs(stats.zscore(dfNew))
print(z)
# Out:
# [[3.73992586e-01 5.50917538e-01 5.61527044e-01 4.32892628e-01
#   3.89714420e-01 8.89917097e-02 9.91371404e-02 7.93615163e-02
#   4.70054703e-01 8.28727336e-01]
#  [2.78288626e-01 5.37798490e-01 5.49636022e-01 1.09251294e-01
#   1.66823631e-01 3.99758288e-02 1.03711114e-01 9.08622542e-01
#   6.91242174e-02 2.18619716e-01]
#  [4.45995304e-01 6.13345596e-01 6.26818617e-01 1.11580463e-01
#   4.39839485e-01 2.33069637e-01 9.35204758e-02 1.22364157e-01
#   5.08546431e-01 6.99402460e-01]
#  [3.84758084e-01 6.41410276e-01 6.57995633e-01 2.36636723e-01
#   6.60610702e-01 1.90612430e-01 9.41378467e-02 2.29298240e-01
#   7.17559661e-01 7.54790870e-01]
#  [2.71187350e-01 5.79769564e-01 5.92893390e-01 1.58999703e+00
#   5.21558167e-01 3.08095188e-01 9.83879087e-02 1.84977891e-01
#   4.72417820e-01 7.78082188e-01]
#  [1.53039412e+00 3.18614381e-01 3.20430698e-01 1.43599598e+00
#   3.83800134e-01 5.64007936e-02 9.92761203e-02 1.11554482e+00
#   2.83176585e-01 4.13734737e-01]
# ...

# %%
# Detecting outliers by defining a threshold to identify an outlier.
tre1 =4
print(np.where(z > tre1))
# Out:
# (array([38, 40, 47, 74, 74, 74, 74, 74, 74, 74], dtype=int64), array([6, 5, 9, 1, 2, 4, 5, 7, 8, 9], dtype=int64))

# %%
# Removing outliers
#df_o= dft[(z < tre1).all(axis=1)]
df_o= df[(z<tre1).all(axis=1)]

# %%
# Explanation: The first array contains the list of row numbers and second array respective column numbers, 
# which mean z[55][1] have a Z-score higher than 10.
# See example:
print(z[10][1])
type(df_o)
df_o.dtypes 
##Output cleaned data to csv
#housepy_df.to_csv("housepy_cleaned.csv", index=False, header=True)
# Out:
# 0.5314794396988964
# Zip Code       float64
# List Price     float64
# Close Price    float64
# Area           float64
# Sq Ft Total    float64
# Lot Size       float64
# Year Built     float64
# Bedrooms       float64
# Baths Total    float64
# CDOM           float64
# dtype: object

# %%
#Indexing
df_o.head()
#df_o.dtypes              #Z_Score method
#df_c=df_o.reset_index()  #Z_Score method
#df_c.head(10)
# Out:
#                               Zip Code     List Price    Close Price  \
# Market Area
# 1960/Cypress              77065.000000  199878.748808  195227.662957
# 1960/Cypress Creek North  77079.121508  207676.377793  201742.322626
# 1960/Cypress Creek South  77054.375706  162773.096673  159456.775267
# Aldine Area               77063.411507  146092.163843  142376.018107
# Alief                     77080.169330  182729.837149  178043.177970
#
#                                Area  Sq Ft Total      Lot Size   Year Built  \
# Market Area
# 1960/Cypress              10.116057  2155.307080  10035.665597  1987.388712
# 1960/Cypress Creek North  13.057263  2804.455944  12433.456964  1982.190642
# 1960/Cypress Creek South  13.036095  2096.840945   7356.938732  1993.771743
# Aldine Area               16.200643  1839.332254   8146.311971  1993.070134
# Alief                     28.499784  2001.523851   5962.048047  1988.240173
#
#                           Bedrooms  Baths Total       CDOM
# ...

# %%
# IQR score
Q1 = classes.quantile(0.25)
Q3 = classes.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Zip Code           65.403406
# List Price     314876.572975
# Close Price    307931.484125
# Area               12.917427
# Sq Ft Total       955.559938
# Lot Size         2508.897773
# Year Built         15.345555
# Bedrooms            0.488943
# Baths Total         0.649516
# CDOM               52.173938
# dtype: float64

# %%
print(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
# Out:
#                                    Zip Code  List Price  Close Price   Area  \
# Market Area
# 1960/Cypress                          False       False        False  False
# 1960/Cypress Creek North              False       False        False  False
# 1960/Cypress Creek South              False       False        False  False
# Aldine Area                           False       False        False  False
# Alief                                 False       False        False  False
# Atascocita North                      False       False        False  False
# Atascocita South                      False       False        False  False
# Baytown/Harris County                 False       False        False  False
# Bear Creek South                      False       False        False  False
# Bellaire Area                         False       False        False  False
# Braeswood Place                       False       False        False  False
# ...

# %%
# Removing Outliers
df_o1 = df[(z < tre1).all(axis=1)]
df_o1.shape
df.shape
# Out:
# (100, 10)

# %%
# Index 
df_o1.dtypes             # IQR method
#df_c1=df_o1.reset_index()
df_o1.head()
# Out:
#                               Zip Code     List Price    Close Price  \
# Market Area
# 1960/Cypress              77065.000000  199878.748808  195227.662957
# 1960/Cypress Creek North  77079.121508  207676.377793  201742.322626
# 1960/Cypress Creek South  77054.375706  162773.096673  159456.775267
# Aldine Area               77063.411507  146092.163843  142376.018107
# Alief                     77080.169330  182729.837149  178043.177970
#
#                                Area  Sq Ft Total      Lot Size   Year Built  \
# Market Area
# 1960/Cypress              10.116057  2155.307080  10035.665597  1987.388712
# 1960/Cypress Creek North  13.057263  2804.455944  12433.456964  1982.190642
# 1960/Cypress Creek South  13.036095  2096.840945   7356.938732  1993.771743
# Aldine Area               16.200643  1839.332254   8146.311971  1993.070134
# Alief                     28.499784  2001.523851   5962.048047  1988.240173
#
#                           Bedrooms  Baths Total       CDOM
# ...

# %%
# See new box plots
fig, ax = plt.subplots(figsize=(16,8))
boxplot = df_o.boxplot(column=['List Price', 'Close Price', 'CDOM', 'Sq Ft Total', 'Lot Size', 'Year Built', 'Bedrooms', 'CDOM'])

#fig, ax = plt.subplots(figsize=(16,8))
#ax.scatter(df_o['Close Price'], df_o['CDOM'])
#ax.set_xlabel('Close Close')
#ax.set_ylabel('List Price')
#plt.show()

# %%
# CAlCULATIONS
# RANDOM FOREST ANALYSIS
#One-hot encoded categorical variables: # Data Preparation
#Converted to arrays
#Split data into training and testing sets
#-------------------
# Data Preparation
dfNew.head()
#df.columns
#df.dtypes 
features=dfNew 
type(features)
#features.iloc[:,5:].head(5)
features.head(5)
# Drop Market Area and School District

# Labels are the values we want to predict
labels = np.array(features['Zip Code'])
# Remove the labels from the features
# axis 1 refers to the columns
features= features.drop('Zip Code', axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)

# %%
# Training and Testing Sets
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 100)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
#Training Features Shape: (54, 9)
#Training Labels Shape: (154)
#Testing Features Shape: (19, 9)
#Testing Labels Shape: (19)
# Out:
# Training Features Shape: (54, 9)
# Training Labels Shape: (54,)
# Testing Features Shape: (19, 9)
# Testing Labels Shape: (19,)

# %%
# The baseline predictions are the historical averages
baseline_preds = test_features[:, feature_list.index('List Price')]
# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2))
#Average baseline error:  5.06 degrees.
# Out:
# Average baseline error:  203405.83

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 100, random_state = 100)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
#Mean Absolute Error: 8512.05 degrees
# Out:
# Mean Absolute Error: 104.27 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
#Accuracy: 95.96 %.
    # That looks pretty good! Our model has learned how to predict the List price as a function of list and close price in Houston with 95.96% accuracy.
# Out:
# Accuracy: 99.87 %.

# %%
#conda install GraphViz

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names = feature_list, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
# ...

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Baths Total          Importance: 0.26
# Variable: Bedrooms             Importance: 0.18
# Variable: List Price           Importance: 0.11
# Variable: Area                 Importance: 0.1
# Variable: Sq Ft Total          Importance: 0.09
# Variable: Close Price          Importance: 0.08
# Variable: Lot Size             Importance: 0.08
# Variable: CDOM                 Importance: 0.07
# Variable: Year Built           Importance: 0.04

# %%
# New random forest with only the two most important variables
rf_most_important = RandomForestRegressor(n_estimators= 1000, random_state=100)
# Extract the two most important features
important_indices = [feature_list.index('Close Price'), feature_list.index('CDOM')]
train_important = train_features[:, important_indices]
test_important = test_features[:, important_indices]
# Train the random forest
rf_most_important.fit(train_important, train_labels)
# Make predictions and determine the error
predictions = rf_most_important.predict(test_important)
errors = abs(predictions - test_labels)
# Display the performance metrics
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
mape = np.mean(100 * (errors / test_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')

#Note:
#This tells us that we actually do not need all the data we collected to make accurate predictions! If we were to continue using this model, we could only collect the two variables and achieve nearly the same performance.
# Out:
# Mean Absolute Error: 109.73 degrees.
# Accuracy: 99.86 %.

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# Use datetime for creating date objects for plotting
import datetime
# Dates of training values
months = features[:, feature_list.index('month')]
days = features[:, feature_list.index('day')]
years = features[:, feature_list.index('year')]
# List and then convert to datetime object
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]
# Dataframe with true values and dates
true_data = pd.DataFrame(data = {'date': dates, 'actual': labels})
# Dates of predictions
months = test_features[:, feature_list.index('month')]
days = test_features[:, feature_list.index('day')]
years = test_features[:, feature_list.index('year')]
# Column of dates
test_dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
# Convert to datetime objects
test_dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in test_dates]
# Dataframe with predictions and dates
predictions_data = pd.DataFrame(data = {'date': test_dates, 'prediction': predictions})
# Plot the actual values
plt.plot(true_data['date'], true_data['actual'], 'b-', label = 'actual')
# Plot the predicted values
plt.plot(predictions_data['date'], predictions_data['prediction'], 'ro', label = 'prediction')
plt.xticks(rotation = '60'); 
plt.legend()
# Graph labels
plt.xlabel('Date'); plt.ylabel('Maximum Temperature (F)'); plt.title('Actual and Predicted Values');

# %%
# Make the data accessible for plotting
true_data['temp_1'] = features[:, feature_list.index('temp_1')]
true_data['average'] = features[:, feature_list.index('average')]
true_data['friend'] = features[:, feature_list.index('friend')]
# Plot all the data as lines
plt.plot(true_data['date'], true_data['actual'], 'b-', label  = 'actual', alpha = 1.0)
plt.plot(true_data['date'], true_data['temp_1'], 'y-', label  = 'temp_1', alpha = 1.0)
plt.plot(true_data['date'], true_data['average'], 'k-', label = 'average', alpha = 0.8)
plt.plot(true_data['date'], true_data['friend'], 'r-', label = 'friend', alpha = 0.3)
# Formatting plot
plt.legend(); plt.xticks(rotation = '60');
# Lables and title
plt.xlabel('Date'); plt.ylabel('Maximum Temperature (F)'); plt.title('Actual Max Temp and Variables');

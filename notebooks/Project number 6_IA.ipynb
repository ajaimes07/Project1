# %%
import pandas as pd
import numpy as np
import matplotlib as plt

csv_path = "Housepy_raw.csv"
csv_path2="HouseHold income 2013.2017.csv"
housepy_df = pd.read_csv(csv_path)
housepy_df.head()
householdincome = pd.read_csv(csv_path2)
householdincome.head()
housepy_df.head()
# Out:
#    MLS Number  Property Type Status Street Number    Street Name Unit Number  \
# 0    85605507  Single-Family   Sold           823          Loper         NaN
# 1    67891056  Single-Family   Sold          9009       Freeland         NaN
# 2    97810747  Single-Family   Sold         17503  Waverly Grove         NaN
# 3    94468427  Single-Family   Sold          6619    Briar Glade         NaN
# 4    19671424  Single-Family   Sold           546       Glenvale         NaN
#
#   City/Location  Zip Code  County List Price  ...  \
# 0       Houston     77017  Harris   $44,500   ...
# 1       Houston     77075  Harris   $65,000   ...
# 2       Houston     77084  Harris   $90,000   ...
# 3       Houston     77072  Harris   $85,900   ...
# 4       Houston     77060  Harris  $105,000   ...
#
#               List Office Name List Agent MLSID  List Agent Full Name  \
# 0             The Listing Firm         oronding         Osaan Ronding
# ...

# %%
#dropping columns that wont be used to tell us anything

housepy_clean = housepy_df[["MLS Number", "Street Number", "Street Name", "City/Location", "Zip Code", "List Price",
                           "Close Price", "Close Date", "Area", "Subdivision", "Market Area", "School District",
                           "School Elementary", "School Middle", "School High", "Sq Ft Total", "Price Sq Ft Sold", "Lot Size",
                          "Year Built", "Bedrooms", "Baths Total", "New Construction", "Pool Private", "No Of Garage Cap",
                          "Style", "CDOM"]]
householdincome_clean=householdincome[["Year","Household Income by Race","Geography"]]
housepy_clean.head(5)
housepy_clean['Close Price'] = housepy_clean['Close Price'].apply(lambda x: x.replace("$", ""))
housepy_clean['Close Price'] = housepy_clean['Close Price'].apply(lambda x: x.replace(",", ""))
housepy_clean['Close Price'] = housepy_clean['Close Price'].astype(int)
housepy_clean.head()
len(housepy_clean)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# get the median for harris county
# The federal Department of Housing and Urban Development (HUD) defines an "affordable dwelling" as one that a household can obtain for 30 percent or less of its income. ... So, by this definition, a dwelling is considered "affordable" for low-income families if it costs less than 24 percent of the area median 
# income.May 11, 2015


year_2017=householdincome_clean[householdincome_clean.Year == 2017]
year_2017
# Out:
#     Year  Household Income by Race                             Geography
# 0   2017                     93645                  Fort Bend County, TX
# 1   2017                     62922  Houston-The Woodlands-Sugar Land, TX
# 2   2017                     57652                         United States
# 3   2017                     76426                   Brazoria County, TX
# 4   2017                     74368                   Chambers County, TX
# 5   2017                     57051                                 Texas
# 6   2017                     53506                     Waller County, TX
# 7   2017                     74323                 Montgomery County, TX
# 8   2017                     48344                    Liberty County, TX
# 9   2017                     57791                     Harris County, TX
# 10  2017                     65702                  Galveston County, TX

# %%
medianincome_2017= year_2017.get_value(9, 'Household Income by Race')
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.

# %%
#Define affordable housing
affordable_housing=medianincome_2017*int(4.12)
# affordable_housing='${:,.2f}'.format(affordable_housing)
print(f"the affordable housing income is {affordable_housing}")
# '${:,.2f}'.format(affordable_housing)
# Out:
# the affordable housing income is 231164

# %%
Affordable_housing_table=housepy_clean.loc[housepy_clean['Close Price'] <= 231164]
Affordable_housing_table 

# housepy_clean['Close Price'] <= year_2017.apply(lambda x: 'value if condition is met' if x condition else 'value if condition is not met')

# if affordable_housing <= Close Price:
#     print Area
# Out:
#        MLS Number Street Number        Street Name City/Location  Zip Code  \
# 0        85605507           823              Loper       Houston     77017
# 1        67891056          9009           Freeland       Houston     77075
# 2        97810747         17503      Waverly Grove       Houston     77084
# 3        94468427          6619        Briar Glade       Houston     77072
# 4        19671424           546           Glenvale       Houston     77060
# 5        32119336         15243           La Jolla       Houston     77060
# 6        89645275         11118              Melba       Houston     77041
# 7        20227612         11055     Rustling Winds       Houston     77064
# 8        69972345         15210           Paladora       Houston     77083
# 9        20751448         10031            Farrell       Houston     77070
# 10       61214712          5539     Woodland Glade       Houston     77066
# ...

# %%
# housepy_clean.dtypes
# type(housepy_clean["Close Price"][0])
Affordable_housing_table = Affordable_housing_table[["MLS Number", "City/Location", "Zip Code", "List Price",
                                                   "Close Price", "Market Area","Sq Ft Total", "Price Sq Ft Sold", "Lot Size",
                                                   "Bedrooms", "Baths Total", "Pool Private", "No Of Garage Cap","Style"]]
len(Affordable_housing_table)
Affordable_housing_table
# Out:
#        MLS Number City/Location  Zip Code List Price  Close Price  \
# 0        85605507       Houston     77017   $44,500         44500
# 1        67891056       Houston     77075   $65,000         60000
# 2        97810747       Houston     77084   $90,000         78500
# 3        94468427       Houston     77072   $85,900         85000
# 4        19671424       Houston     77060  $105,000         94000
# 5        32119336       Houston     77060  $105,000         95000
# 6        89645275       Houston     77041  $110,000        108000
# 7        20227612       Houston     77064  $121,999        115000
# 8        69972345       Houston     77083  $121,200        131200
# 9        20751448       Houston     77070  $134,900        132000
# 10       61214712       Houston     77066  $139,229        139229
# 11       21296935       Houston     77074  $169,900        140000
# 12       45757106       Houston     77053  $140,800        141000
# ...

# %%
# Out:
#   File "<ipython-input-115-033448d6f87b>", line 1
#     Affordable_housing_table[Affordable_housing_table.[Market Area] == 'Hobby Area']
#                                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Warmup!
# ## Make sure to check in and pull the repo!
# ## This file is in the Class Repo under the new Warmups folder!

# %%
import pandas as pd
from random import random
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### Create a DataFrame That you will use to create a scatter matrix

# %%
my_dict = {
    'x': [random() for i in range(1000)],
    'y': [random() for i in range(1000)],
    'z': [random() for i in range(1000)]
}

# %%
Scatterframe_df = pd.DataFrame(my_dict)
Scatterframe_df
# Out:
#             x         y         z
# 0    0.698087  0.464729  0.387580
# 1    0.927856  0.960806  0.094685
# 2    0.706590  0.970137  0.346919
# 3    0.530075  0.005921  0.103627
# 4    0.310129  0.530614  0.285703
# 5    0.614090  0.902111  0.084791
# 6    0.321085  0.253162  0.342229
# 7    0.608051  0.787450  0.513297
# 8    0.138528  0.517661  0.956049
# 9    0.737046  0.617397  0.197907
# 10   0.861951  0.607660  0.456771
# 11   0.109952  0.396770  0.977955
# 12   0.951733  0.937740  0.214483
# 13   0.560714  0.128955  0.609551
# 14   0.912143  0.377623  0.373840
# 15   0.543776  0.526961  0.487981
# 16   0.153769  0.990147  0.241657
# 17   0.043612  0.308742  0.563649
# 18   0.175785  0.479129  0.585443
# 19   0.010342  0.375907  0.827704
# 20   0.347832  0.745159  0.190694
# 21   0.041285  0.167429  0.827854
# 22   0.002009  0.164284  0.254465
# 23   0.911155  0.763427  0.545665
# 24   0.774763  0.760287  0.753010
# 25   0.775475  0.230763  0.338371
# ...

# %% [markdown]
# <h3>Create a scatter matrix based on the DataFrame you created

# %%
plt = scatter_matrix(Scatterframe_df, alpha=0.2)

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1eb00ff78cf2> in <module>
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined

# %%
#f = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
scatter_matrix(Scatterframe_df, alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B54E3BCE80>,
# ...
#       dtype=object)

# %% [markdown]
# # Bonus!
# ###Create a Function That will take in a dataframe and a sample size
# in ordert to return an DataFrame scatter!

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B54E209630>,
# ...
#       dtype=object)

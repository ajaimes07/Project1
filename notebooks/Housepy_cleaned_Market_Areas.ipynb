# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import string as string


from scipy.stats import linregress

csv_path = "Downloads/Housepy_raw.csv"
housepyraw_df = pd.read_csv(csv_path)
housepyraw_df.head()
# Out:
# C:\Users\easha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    MLS Number  Property Type Status Street Number    Street Name Unit Number  \
# 0    85605507  Single-Family   Sold           823          Loper         NaN
# 1    67891056  Single-Family   Sold          9009       Freeland         NaN
# 2    97810747  Single-Family   Sold         17503  Waverly Grove         NaN
# 3    94468427  Single-Family   Sold          6619    Briar Glade         NaN
# 4    19671424  Single-Family   Sold           546       Glenvale         NaN
#
#   City/Location  Zip Code  County List Price  ...  \
# 0       Houston     77017  Harris   $44,500   ...
# 1       Houston     77075  Harris   $65,000   ...
# 2       Houston     77084  Harris   $90,000   ...
# 3       Houston     77072  Harris   $85,900   ...
# 4       Houston     77060  Harris  $105,000   ...
#
#               List Office Name List Agent MLSID  List Agent Full Name  \
# 0             The Listing Firm         oronding         Osaan Ronding
# 1    Mission Real Estate Group            jiley              Joe Iley
# 2  Intero Real Estate Services            baumd       D'Evereaux Baum
# 3        Van Slyke Real Estate            vansh       Helen Van Slyke
# 4   RE/MAX Northwest, REALTORS          joeluis            Jose Soria
#
#   Selling Office MLSID             Selling Office Name Selling Agent MLSID  \
# 0               DAFA01                   Reward Realty            GREENMIC
# 1               ILEY01       Mission Real Estate Group               jiley
# 2               GGPR24               BHGRE Gary Greene            JilSmith
# 3               RELM01  Realm Real Estate Professional             shaleem
# 4               KWPR01   Keller Williams Professionals              smgeer
#
#   Selling Agent Full Name             Realist Owner Name  \
# 0           Michael Green                            NaN
# 1                Joe Iley  Trusted Legacy Hse Buyers Inc
# 2              Jill Smith                            NaN
# 3             Shah Haleem      Hsbc Bank Usa Na 2006-Nc3
# 4            Shannon Geer                            NaN
#
#   Last Change Timestamp      List Date
# 0                   NaN  12/9/2014 0:00
# 1                   NaN  7/15/2015 0:00
# 2                   NaN  3/16/2015 0:00
# 3                   NaN   6/1/2015 0:00
# 4                   NaN  3/23/2015 0:00
#
# [5 rows x 53 columns]

# %%
#dropping columns that wont be used to tell us anything
housepy_df = housepyraw_df[["MLS Number", "Street Number", "Street Name", "City/Location", "Zip Code", "List Price",
                           "Close Price", "Close Date", "Area", "Subdivision", "Market Area", "School District",
                           "School Elementary", "School Middle", "School High", "Sq Ft Total", "Price Sq Ft Sold", "Lot Size",
                          "Year Built", "Bedrooms", "Baths Total", "New Construction", "Pool Private", "No Of Garage Cap",
                          "Style", "CDOM"]]
housepy_df.head()
# Out:
#    MLS Number Street Number    Street Name City/Location  Zip Code List Price  \
# 0    85605507           823          Loper       Houston     77017   $44,500
# 1    67891056          9009       Freeland       Houston     77075   $65,000
# 2    97810747         17503  Waverly Grove       Houston     77084   $90,000
# 3    94468427          6619    Briar Glade       Houston     77072   $85,900
# 4    19671424           546       Glenvale       Houston     77060  $105,000
#
#   Close Price     Close Date  Area                Subdivision  ...  \
# 0    $44,500   8/3/2015 0:00   3.0         Oak Meadows Sec 01  ...
# 1    $60,000   8/3/2015 0:00   3.0                  Easthaven  ...
# 2    $78,500   8/3/2015 0:00   8.0               Ashley Grove  ...
# 3    $85,000   8/3/2015 0:00  28.0  Brays Village East Sec 02  ...
# 4    $94,000   8/3/2015 0:00  12.0             Colonial Hills  ...
#
#   Price Sq Ft Sold Lot Size Year Built Bedrooms Baths Total  New Construction  \
# 0          $35.83    6600.0     1950.0        3         1.0             False
# 1          $45.87    7500.0     1977.0        3         2.0             False
# 2          $94.69    3900.0     1984.0        2         1.0             False
# 3          $46.60    4050.0     1980.0        3         2.0             False
# 4          $86.32    6090.0     1968.0        3         1.1             False
#
#   Pool Private  No Of Garage Cap        Style  CDOM
# 0        False                 2  Traditional    81
# 1        False                 0  Traditional    19
# 2        False                 1  Traditional    70
# 3        False                 2  Traditional    40
# 4        False                 1  Traditional    98
#
# [5 rows x 26 columns]

# %%
#Output cleaned data to csv
#housepy_df.to_csv("housepy_cleaned.csv", index=False, header=True)

# %%
#Clean the string data type columns

housepy_df.dtypes
# Out:
# MLS Number             int64
# Street Number         object
# Street Name           object
# City/Location         object
# Zip Code               int64
# List Price            object
# Close Price           object
# Close Date            object
# Area                 float64
# Subdivision           object
# Market Area           object
# School District       object
# School Elementary     object
# School Middle         object
# School High           object
# Sq Ft Total          float64
# Price Sq Ft Sold      object
# Lot Size             float64
# Year Built           float64
# Bedrooms               int64
# Baths Total          float64
# New Construction        bool
# Pool Private            bool
# No Of Garage Cap       int64
# Style                 object
# CDOM                   int64
# dtype: object

# %%
housepy_df['Close Price'] = housepy_df['Close Price'].apply(lambda x: x.replace("$", ""))
housepy_df.head()
# Out:
# C:\Users\easha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    MLS Number Street Number    Street Name City/Location  Zip Code List Price  \
# 0    85605507           823          Loper       Houston     77017   $44,500
# 1    67891056          9009       Freeland       Houston     77075   $65,000
# 2    97810747         17503  Waverly Grove       Houston     77084   $90,000
# 3    94468427          6619    Briar Glade       Houston     77072   $85,900
# 4    19671424           546       Glenvale       Houston     77060  $105,000
#
#   Close Price     Close Date  Area                Subdivision  ...  \
# 0     44,500   8/3/2015 0:00   3.0         Oak Meadows Sec 01  ...
# 1     60,000   8/3/2015 0:00   3.0                  Easthaven  ...
# 2     78,500   8/3/2015 0:00   8.0               Ashley Grove  ...
# 3     85,000   8/3/2015 0:00  28.0  Brays Village East Sec 02  ...
# 4     94,000   8/3/2015 0:00  12.0             Colonial Hills  ...
#
#   Price Sq Ft Sold Lot Size Year Built Bedrooms Baths Total  New Construction  \
# 0          $35.83    6600.0     1950.0        3         1.0             False
# 1          $45.87    7500.0     1977.0        3         2.0             False
# 2          $94.69    3900.0     1984.0        2         1.0             False
# 3          $46.60    4050.0     1980.0        3         2.0             False
# 4          $86.32    6090.0     1968.0        3         1.1             False
#
#   Pool Private  No Of Garage Cap        Style  CDOM
# 0        False                 2  Traditional    81
# 1        False                 0  Traditional    19
# 2        False                 1  Traditional    70
# 3        False                 2  Traditional    40
# 4        False                 1  Traditional    98
#
# [5 rows x 26 columns]

# %%
housepy_df['Close Price'] = housepy_df['Close Price'].apply(lambda x: x.replace(",", ""))
housepy_df.head()
housepy_df.dtypes
# Out:
# C:\Users\easha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# MLS Number             int64
# Street Number         object
# Street Name           object
# City/Location         object
# Zip Code               int64
# List Price            object
# Close Price           object
# Close Date            object
# Area                 float64
# Subdivision           object
# Market Area           object
# School District       object
# School Elementary     object
# School Middle         object
# School High           object
# Sq Ft Total          float64
# Price Sq Ft Sold      object
# Lot Size             float64
# Year Built           float64
# Bedrooms               int64
# Baths Total          float64
# New Construction        bool
# Pool Private            bool
# No Of Garage Cap       int64
# Style                 object
# CDOM                   int64
# dtype: object

# %%
housepy_df['Close Price'] = housepy_df['Close Price'].astype(int)
housepy_df.head()
# Out:
# C:\Users\easha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    MLS Number Street Number    Street Name City/Location  Zip Code List Price  \
# 0    85605507           823          Loper       Houston     77017   $44,500
# 1    67891056          9009       Freeland       Houston     77075   $65,000
# 2    97810747         17503  Waverly Grove       Houston     77084   $90,000
# 3    94468427          6619    Briar Glade       Houston     77072   $85,900
# 4    19671424           546       Glenvale       Houston     77060  $105,000
#
#    Close Price     Close Date  Area                Subdivision  ...  \
# 0        44500  8/3/2015 0:00   3.0         Oak Meadows Sec 01  ...
# 1        60000  8/3/2015 0:00   3.0                  Easthaven  ...
# 2        78500  8/3/2015 0:00   8.0               Ashley Grove  ...
# 3        85000  8/3/2015 0:00  28.0  Brays Village East Sec 02  ...
# 4        94000  8/3/2015 0:00  12.0             Colonial Hills  ...
#
#   Price Sq Ft Sold Lot Size Year Built Bedrooms Baths Total  New Construction  \
# 0          $35.83    6600.0     1950.0        3         1.0             False
# 1          $45.87    7500.0     1977.0        3         2.0             False
# 2          $94.69    3900.0     1984.0        2         1.0             False
# 3          $46.60    4050.0     1980.0        3         2.0             False
# 4          $86.32    6090.0     1968.0        3         1.1             False
#
#   Pool Private  No Of Garage Cap        Style  CDOM
# 0        False                 2  Traditional    81
# 1        False                 0  Traditional    19
# 2        False                 1  Traditional    70
# 3        False                 2  Traditional    40
# 4        False                 1  Traditional    98
#
# [5 rows x 26 columns]

# %% [markdown]
# dict_list = []
# for school in school_df["school_name"].unique().tolist():
#     temp_dict = {"School Name": school_df.loc[school_df["school_name"]==school]["school_name"].max(),
#                  "School Type": school_df.loc[school_df["school_name"]==school]["type"].max(),
#                 "Total Student": len(school_df.loc[school_df["school_name"]==school]),
#                 "Total Budget": school_df.loc[school_df["school_name"]==school]["budget"].max(),
#                 "Per Stu Budget": (school_df.loc[school_df["school_name"]==school]["budget"].max())/(len(school_df.loc[school_df["school_name"]==school])),
#                 "Math Avg Score": school_df.loc[school_df["school_name"]==school]["math_score"].mean(),
#                 "Reading Avg Score": school_df.loc[school_df["school_name"]==school]["reading_score"].mean(),
#                 "Math Pct Pass": ((len(school_df.loc[(school_df["school_name"]==school) & (school_df["math_score"]>69)]))/(len(school_df.loc[school_df["school_name"]==school])))*100,
#                 "Reading Pct Pass": ((len(school_df.loc[(school_df["school_name"]==school)&(school_df["reading_score"]>69)]))/(len(school_df.loc[school_df["school_name"]==school])))*100,
#                 "Overall Pass Rate": ((((len(school_df.loc[(school_df["school_name"]==school) & (school_df["math_score"]>69)]))/(len(school_df.loc[school_df["school_name"]==school])))*100 + ((len(school_df.loc[(school_df["school_name"]==school) & (school_df["reading_score"]>69)]))/(len(school_df.loc[school_df["school_name"]==school])))*100)/2)}
#
#     temp_dict_list.append(temp_dict)
# SchoolSummary = pd.DataFrame(temp_dict_list)
# SchoolSummary
#
# "Affordable Housing Percentage": ((len(housepy_df.loc[(housepy_df["Market Area"]==market)&(housepy_df["Close Price"]<242136)]))
#                 /(len(housepy_df.loc[housepy_df["Market Area"]==market])))*100,
#
#
#  Look at which subdivisions are appreciating?
# Which subdivisions declined? Which subdivisions indicate gentrification? Most valued subdivisions in Harris county

# %%
#Creating the total sold column alerts us that there are areas with nothing sold or a blank in the dataset

dict_list = []
for market in housepy_df["Market Area"].unique().tolist():
    temp_dict = {"Market Area": housepy_df.loc[housepy_df["Market Area"]==market]["Market Area"].max(), 
                "Sold Price": housepy_df.loc[housepy_df["Market Area"]==market]["Close Price"].median(),
                "Total Sold": len(housepy_df.loc[housepy_df["Market Area"]==market])} 
    
    dict_list.append(temp_dict)
MarketSummary = pd.DataFrame(dict_list)
MarketSummary
# Out:
#                          Market Area  Sold Price  Total Sold
# 0                         Hobby Area    135950.0        1696
# 1                   Bear Creek South    180000.0        2227
# 2                              Alief    165000.0        2315
# 3                        Aldine Area    141500.0        3424
# 4                     Eldridge North    215000.0        1338
# 5                  Willowbrook South    162000.0        1255
# 6                  Mission Bend Area    163000.0        1025
# 7           1960/Cypress Creek South    156000.0        3186
# 8                         Brays Oaks    210000.0        2329
# 9                       Five Corners    151000.0        1688
# 10                      Huffman Area    157350.0         102
# 11          1960/Cypress Creek North    185000.0        1432
# 12                     Spring Branch    332950.0        4345
# 13                     North Channel    159900.0        3061
# 14               Southbelt/Ellington    175000.0        2668
# 15                     Kingwood East    280000.0         691
# 16                   Sharpstown Area    192500.0         706
# 17              Medical Center South    135194.0        2446
# 18                    Jersey Village    216600.0         754
# 19                  Copperfield Area    214000.0        4198
# 20              Summerwood/Lakeshore    284000.0        1623
# 21              Oak Forest West Area    260000.0         808
# 22                  Katy - Southeast    399500.0         555
# 23                          Pearland    249900.0         146
# 24               Willow Meadows Area    298000.0         614
# 25            Tomball South/Lakewood    201500.0         108
# 26                   Clear Lake Area    240000.0        2821
# 27                   Energy Corridor    340000.0        2252
# 28                     Memorial West    660000.0        1777
# 29           Heights/Greater Heights    480000.0        5020
# ..                               ...         ...         ...
# 73                     Cypress South    197000.0           5
# 74                  Atascocita South    280000.0         119
# 75                  Atascocita North    400000.0          13
# 76          River Oaks Shopping Area    697500.0         256
# 77          Highland Village/Midlane    834950.0         154
# 78                   Tanglewood Area   1492500.0         390
# 79                           Gulfton    201500.0          30
# 80          Shepherd Park Plaza Area    429500.0         317
# 81                  Humble Area West    128000.0          41
# 82                             Other    177500.0          71
# 83            Royden Oaks/Afton Oaks    895000.0         128
# 84                       Spring East    150000.0          17
# 85                          Pasadena    105000.0           7
# 86                  Sugar Land South    288500.0           1
# 87                    Greenway Plaza    824500.0          19
# 88                        Rivercrest   2850000.0          15
# 89             Baytown/Harris County    121500.0           2
# 90                  Humble Area East    189900.0          11
# 91                  Sugar Land North    125000.0           1
# 92                    Kingwood South   1427000.0           2
# 93                   Fall Creek Area    353676.0          87
# 94                      Spring/Klein    199950.0           6
# 95                Downtown - Houston    383250.0           6
# 96                     South Houston    180000.0           3
# 97                       Alvin North    159900.0           2
# 98              Spring/Klein/Tomball    426000.0           2
# 99                       Friendswood    235500.0           1
# 100  Fort Bend County North/Richmond    184000.0           1
# 101                          Webster    284900.0           3
# 102                  Sugar Land West    291884.0           1
#
# [103 rows x 3 columns]

# %%
#Lets Clean the Market Area data because there appears to be a zero sold somewhere in there/ market areas with only one sold.

#MarketSummary.to_csv("Desktop\Cleaning_By_Market_Area.csv", index=False, header=True)

# %%
#Lets drop the rows with the Market Areas with not enough data
housepy_df = housepy_df[housepy_df["Market Area"]!="Other"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Charnwood/Briarbend"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Humble Area West"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Humble Area South"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Gulfton"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Greenway Plaza"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Spring East"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Atascocita North"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Humble Area East"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Pasadena"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Spring/Klein"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Downtown - Houston"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Cypress South"]
housepy_df = housepy_df[housepy_df["Market Area"]!="South Houston"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Webster"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Baytown/Harris County"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Kingwood South"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Alvin North"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Spring/Klein/Tomball"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Sugar Land South"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Sugar Land North"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Friendswood"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Fort Bend County North/Richmond"]
housepy_df = housepy_df[housepy_df["Market Area"]!="Sugar Land West"]

# %%
housepy_df.dropna(inplace=True)

# %%
#The next two cells are creating 3 columns from splitting one

new = housepy_df["Close Date"].str.split("/", n = 1, expand = True) 
  

housepy_df["Month"]= new[0] 
  

housepy_df["DayYear"]= new[1]

# %%
new = housepy_df["DayYear"].str.split("/", n = 1, expand = True) 
  

housepy_df["Day"]= new[0] 
  

housepy_df["Year"]= new[1]

housepy_df.head()
# Out:
#    MLS Number Street Number    Street Name City/Location  Zip Code List Price  \
# 0    85605507           823          Loper       Houston     77017   $44,500
# 1    67891056          9009       Freeland       Houston     77075   $65,000
# 2    97810747         17503  Waverly Grove       Houston     77084   $90,000
# 3    94468427          6619    Briar Glade       Houston     77072   $85,900
# 4    19671424           546       Glenvale       Houston     77060  $105,000
#
#    Close Price     Close Date  Area                Subdivision  ...  \
# 0        44500  8/3/2015 0:00   3.0         Oak Meadows Sec 01  ...
# 1        60000  8/3/2015 0:00   3.0                  Easthaven  ...
# 2        78500  8/3/2015 0:00   8.0               Ashley Grove  ...
# 3        85000  8/3/2015 0:00  28.0  Brays Village East Sec 02  ...
# 4        94000  8/3/2015 0:00  12.0             Colonial Hills  ...
#
#   Baths Total New Construction Pool Private No Of Garage Cap        Style  \
# 0         1.0            False        False                2  Traditional
# 1         2.0            False        False                0  Traditional
# 2         1.0            False        False                1  Traditional
# 3         2.0            False        False                2  Traditional
# 4         1.1            False        False                1  Traditional
#
#    CDOM Month      DayYear  Day       Year
# 0    81     8  3/2015 0:00    3  2015 0:00
# 1    19     8  3/2015 0:00    3  2015 0:00
# 2    70     8  3/2015 0:00    3  2015 0:00
# 3    40     8  3/2015 0:00    3  2015 0:00
# 4    98     8  3/2015 0:00    3  2015 0:00
#
# [5 rows x 30 columns]

# %%
new_dict_list = []
for market in housepy_df["Market Area"].unique().tolist():
    temp_dict1 = {"Market Area": housepy_df.loc[housepy_df["Market Area"]==market]["Market Area"].max(), 
                "Sold Price": housepy_df.loc[housepy_df["Market Area"]==market]["Close Price"].median(),
                "Total Sold": len(housepy_df.loc[housepy_df["Market Area"]==market]),
                 "Affordable Housing Percentage": ((len(housepy_df.loc[(housepy_df["Market Area"]==market)&(housepy_df["Close Price"]<242136)]))
                /(len(housepy_df.loc[housepy_df["Market Area"]==market])))*100,
                 "Year": housepy_df.loc[housepy_df["Market Area"]==market]["Year"]} 
    
    new_dict_list.append(temp_dict1)
MarketSummary2 = pd.DataFrame(new_dict_list)
MarketSummary2.head()
# Out:
#    Affordable Housing Percentage       Market Area  Sold Price  Total Sold  \
# 0                      95.902141        Hobby Area    137200.0        1635
# 1                      86.949924  Bear Creek South    175000.0        1977
# 2                      86.801802             Alief    165000.0        2220
# 3                      99.181401       Aldine Area    140000.0        3054
# 4                      59.298780    Eldridge North    215000.0        1312
#
#                                                 Year
# 0  0        2015 0:00
# 1        2015 0:00
# 75      ...
# 1  2        2015 0:00
# 14       2015 0:00
# 42      ...
# 2  3        2015 0:00
# 66       2015 0:00
# 89      ...
# 3  4        2015 0:00
# 5        2015 0:00
# 16      ...
# 4  6        2015 0:00
# 33       2015 0:00
# 101     ...

# %%
Highest_SoldPrices_df = MarketSummary2.sort_values("Sold Price", ascending=False)
Highest_SoldPrices_df.drop(['Year'], axis=1, inplace=True)
Highest_SoldPrices_df = Highest_SoldPrices_df.set_index("Market Area")
Highest_SoldPrices_df.head()
# Out:
#                    Affordable Housing Percentage  Sold Price  Total Sold
# Market Area
# Rivercrest                              0.000000   2850000.0          15
# River Oaks Area                         0.000000   2078600.0         376
# Memorial Close In                       0.000000   1930000.0         111
# Memorial Villages                       0.000000   1508350.0         947
# Tanglewood Area                         0.260417   1480500.0         384

# %%
MostAffordable_SoldPrices_df = MarketSummary2.sort_values("Sold Price")
MostAffordable_SoldPrices_df.drop(['Year'], axis=1, inplace=True)
MostAffordable_SoldPrices_df = MostAffordable_SoldPrices_df.set_index("Market Area")
MostAffordable_SoldPrices_df.head()
# Out:
#                       Affordable Housing Percentage  Sold Price  Total Sold
# Market Area
# Northeast Houston                         99.506417    104500.0        1013
# Northside                                 77.002584    128500.0        1548
# Denver Harbor                             67.289720    130000.0         535
# Medical Center South                      99.247121    134900.0        2258
# Hobby Area                                95.902141    137200.0        1635

# %%
Sales_2015_df = housepy_df.loc[housepy_df["Year"] == "2015 0:00", :]
Sales_2015_df.drop(["Street Number", "Street Name", "City/Location", "Zip Code", "List Price",
                        "Close Date", "Area", "Subdivision",  "School District",
                           "School Elementary", "School Middle", "School High", "Sq Ft Total", "Price Sq Ft Sold", "Lot Size",
                          "Year Built", "Bedrooms", "Baths Total", "New Construction", "Pool Private", "No Of Garage Cap",
                          "Style", "CDOM", "DayYear", "Day", "Month", "MLS Number", "Year"], axis=1, inplace=True)

Sales_2015_df.head()
# Out:
#    Close Price       Market Area
# 0        44500        Hobby Area
# 1        60000        Hobby Area
# 2        78500  Bear Creek South
# 3        85000             Alief
# 4        94000       Aldine Area

# %%
Sales_2019_df = housepy_df.loc[housepy_df["Year"] == "2019 0:00", :]
Sales_2019_df.drop(["Street Number", "Street Name", "City/Location", "Zip Code", "List Price",
                        "Close Date", "Area", "Subdivision",  "School District",
                           "School Elementary", "School Middle", "School High", "Sq Ft Total", "Price Sq Ft Sold", "Lot Size",
                          "Year Built", "Bedrooms", "Baths Total", "New Construction", "Pool Private", "No Of Garage Cap",
                          "Style", "CDOM", "DayYear", "Day", "Month", "MLS Number", "Year"], axis=1, inplace=True)

Sales_2019_df.head()
# Out:
#        Close Price           Market Area
# 77668       214300          1960/Cypress
# 77669        54000  Medical Center South
# 77670        63000         Denver Harbor
# 77671        88000     Northwest Houston
# 77673       117500     Northwest Houston

# %%
Sales_2015_ByArea = Sales_2015_df.groupby("Market Area").median()
Sales_2015_ByArea.head()
# Out:
#                           Close Price
# Market Area
# 1960/Cypress                 162000.0
# 1960/Cypress Creek North     181500.0
# 1960/Cypress Creek South     138000.0
# Aldine Area                  122715.0
# Alief                        145000.0

# %%
Sales_2019_ByArea = Sales_2019_df.groupby("Market Area").median()
Sales_2019_ByArea.head()
# Out:
#                           Close Price
# Market Area
# 1960/Cypress                 200500.0
# 1960/Cypress Creek North     195000.0
# 1960/Cypress Creek South     167750.0
# Aldine Area                  155000.0
# Alief                        172000.0

# %%
Sales_2019_ByArea.dtypes
# Out:
# Close Price    float64
# dtype: object

# %%
merge = pd.merge(Sales_2015_ByArea, Sales_2019_ByArea, on="Market Area")
merge = merge.rename(columns={"Close Price_x": "Median Sold 2015", "Close Price_y": "Median Sold 2019"})
merge.head()
# Out:
#                           Median Sold 2015  Median Sold 2019
# Market Area
# 1960/Cypress                      162000.0          200500.0
# 1960/Cypress Creek North          181500.0          195000.0
# 1960/Cypress Creek South          138000.0          167750.0
# Aldine Area                       122715.0          155000.0
# Alief                             145000.0          172000.0

# %%
percent_change = round(((merge["Median Sold 2019"])-(merge["Median Sold 2015"]))/(merge["Median Sold 2015"])*100, 2)
percent_change
# Out:
# Market Area
# 1960/Cypress                          23.77
# 1960/Cypress Creek North               7.44
# 1960/Cypress Creek South              21.56
# Aldine Area                           26.31
# Alief                                 18.62
# Atascocita South                     -51.64
# Bear Creek South                      15.68
# Bellaire Area                         -3.91
# Braeswood Place                       -3.32
# Brays Oaks                            13.77
# Briar Hollow                           3.80
# Briargrove                            13.88
# Briargrove Park/Walnutbend             7.41
# Briarmeadow/Tanglewilde               12.73
# Champions Area                        -4.05
# Clear Lake Area                       11.49
# Copperfield Area                      14.56
# Cottage Grove                          9.80
# Cypress North                          3.53
# Denver Harbor                         78.70
# East End Revitalized                  29.61
# Eldridge North                        15.00
# Energy Corridor                        3.66
# Five Corners                          22.86
# Galleria                               3.51
# Garden Oaks                           -3.23
# Heights/Greater Heights               13.98
# Highland Village/Midlane              41.79
# Hobby Area                            34.78
# Huffman Area                         126.60
#                                       ...
# North Channel                         29.45
# Northeast Houston                     56.26
# Northside                             52.41
# Northwest Houston                     30.77
# Oak Forest East Area                  23.52
# Oak Forest West Area                   5.77
# Pearland                              18.23
# Rice Military/Washington Corridor     -3.59
# Rice/Museum District                   2.53
# River Oaks Area                       24.10
# River Oaks Shopping Area               1.68
# Rivercrest                            20.14
# Riverside                             47.67
# Royden Oaks/Afton Oaks                72.66
# Sharpstown Area                       13.07
# Shepherd Park Plaza Area               3.51
# Southbelt/Ellington                   22.58
# Spring Branch                          7.10
# Stafford Area                         26.97
# Summerwood/Lakeshore                   7.01
# Tanglewood Area                      -11.26
# Timbergrove/Lazybrook                 12.71
# Tomball South/Lakewood                48.94
# University Area                       49.38
# Upper Kirby                           -0.40
# Washington East/Sabine                -0.12
# West University/Southside Area         4.17
# Westchase Area                       -24.51
# Willow Meadows Area                   -9.71
# Willowbrook South                     19.59
# Length: 77, dtype: float64

# %%
merge["Percent Change"] = percent_change
merge.head()
# Out:
#                           Median Sold 2015  Median Sold 2019  Percent Change
# Market Area
# 1960/Cypress                      162000.0          200500.0           23.77
# 1960/Cypress Creek North          181500.0          195000.0            7.44
# 1960/Cypress Creek South          138000.0          167750.0           21.56
# Aldine Area                       122715.0          155000.0           26.31
# Alief                             145000.0          172000.0           18.62

# %%
appreciate_merge_df = merge.sort_values("Percent Change", ascending=False)

#Highest_SoldPrices_df = Highest_SoldPrices_df.set_index("Market Area")
appreciate_merge_df.head()
# Out:
#                         Median Sold 2015  Median Sold 2019  Percent Change
# Market Area
# Huffman Area                    140250.0          317804.5          126.60
# Denver Harbor                    84500.0          151000.0           78.70
# Royden Oaks/Afton Oaks          722500.0         1247500.0           72.66
# Northeast Houston                79995.0          125000.0           56.26
# Northside                       101700.0          155000.0           52.41

# %%
depreciate_merge_df = merge.sort_values("Percent Change")
depreciate_merge_df.head()
# Out:
#                          Median Sold 2015  Median Sold 2019  Percent Change
# Market Area
# Atascocita South                 565000.0          273225.0          -51.64
# Westchase Area                   731200.0          552000.0          -24.51
# Knollwood/Woodside Area          465000.0          389500.0          -16.24
# Tanglewood Area                 1665000.0         1477500.0          -11.26
# Meyerland Area                   410000.0          366117.5          -10.70
